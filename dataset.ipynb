# %%
import pandas as pd

# %%
dataset = pd.read_csv("ImdbTopMovies.csv")
dataset
# Out:
#                     Title  Year
# 0                 The Kid  1921
# 1             City Lights  1931
# 2                       M  1931
# 3            Modern Times  1936
# 4      The Great Dictator  1940
# ..                    ...   ...
# 95  The Dark Knight Rises  2012
# 96           Interstellar  2014
# 97               Whiplash  2014
# 98                 Dangal  2016
# 99                  Logan  2017
#
# [100 rows x 2 columns]

# %%
dataset.head()

# %%
dataset.head(7)

# %%
dataset.tail()

# %%
dataset.tail(3)

# %%
dataset.info()

# %%
dataset.shape

# %%
dataset.columns

# %%
dataset.rename(
 columns = {
     "title":"name of movies",
     "year":"year"
     }
)

# %%
dataset.sum()

# %%
dataset.mean()

# %%
dataset.describe()

# %%
dataset.loc[25]

# %%
dataset.loc[78]
# Out:
# Title    City of God
# Year            2002
# Name: 78, dtype: object

# %%
dataset.loc[0:60]
dataset.loc[60:90]
# Out:
#                                                 Title  Year
# 60                                         Braveheart  1995
# 61                                          Toy Story  1995
# 62                                  Life Is Beautiful  1997
# 63                                  Princess Mononoke  1997
# 64                                Saving Private Ryan  1998
# 65                                 American History X  1998
# 66                                         Fight Club  1999
# 67                                         The Matrix  1999
# 68                                     The Green Mile  1999
# 69                                    American Beauty  1999
# 70                                          Gladiator  2000
# 71                                            Memento  2000
# 72                                Requiem for a Dream  2000
# 73                                             Snatch  2000
# 74  The Lord of the Rings: The Fellowship of the Ring  2001
# ...
